# %%
import pandas as pd

data = pd.read_csv('prepared_data_13k.csv', sep=';', index_col=False)
data.drop(data.columns[[0]], axis=1, inplace=True)

data
# Out:
#                  username  follower_count  following_count  media_count  \
# 0       ilya_fisher_volga             100              124           88
# 1            utkina_maria             265              360           20
# 2          ilya_tikhobaev              30               29            1
# 3             boris_ganin              35               61            9
# 4        maksim.kyrochkin             248              161           90
# ...                   ...             ...              ...          ...
# 12933            sly_kisa             690              160           85
# 12934          cat_kyzia_              70                7          140
# 12935       1sergo_story1             507              686           30
# 12936          _19sabina_             740              198            3
# 12937  bobrovskii.dmitrii              41               70            2
#
#                        name                                         biography  \
# ...

# %% [markdown]
# ## For fakes prediction

# %%
data.loc[data['label'] == 2, 'label'] = 0
data
# Out:
#                  username  follower_count  following_count  media_count  \
# 0       ilya_fisher_volga             100              124           88
# 1            utkina_maria             265              360           20
# 2          ilya_tikhobaev              30               29            1
# 3             boris_ganin              35               61            9
# 4        maksim.kyrochkin             248              161           90
# ...                   ...             ...              ...          ...
# 12933            sly_kisa             690              160           85
# 12934          cat_kyzia_              70                7          140
# 12935       1sergo_story1             507              686           30
# 12936          _19sabina_             740              198            3
# 12937  bobrovskii.dmitrii              41               70            2
#
#                        name                                         biography  \
# ...

# %% [markdown]
# ## For spammer prediction

# %%
data.loc[data['label'] == 1, 'label'] = 0
data.loc[data['label'] == 2, 'label'] = 1
data
# Out:
#                  username  follower_count  following_count  media_count  \
# 0       ilya_fisher_volga             100              124           88
# 1            utkina_maria             265              360           20
# 2          ilya_tikhobaev              30               29            1
# 3             boris_ganin              35               61            9
# 4        maksim.kyrochkin             248              161           90
# ...                   ...             ...              ...          ...
# 12933            sly_kisa             690              160           85
# 12934          cat_kyzia_              70                7          140
# 12935       1sergo_story1             507              686           30
# 12936          _19sabina_             740              198            3
# 12937  bobrovskii.dmitrii              41               70            2
#
#                        name                                         biography  \
# ...

# %% [markdown]
# # Making features

# %%
numeric_columns = [column for column in data if data[column].dtype != 'object']

features = data[numeric_columns].drop(['label', 'name_has_digits', 'bio_has_digits', 'have_com_links', 'bio_len', 'name_len'], axis=1)
labels = data['label']
features
# Out:
#        follower_count  following_count  media_count  isprivate  \
# 0                 100              124           88          0
# 1                 265              360           20          1
# 2                  30               29            1          0
# 3                  35               61            9          0
# 4                 248              161           90          0
# ...               ...              ...          ...        ...
# 12933             690              160           85          0
# 12934              70                7          140          0
# 12935             507              686           30          0
# 12936             740              198            3          1
# 12937              41               70            2          1
#
#        bio_word_count  name_word_count  have_ru_links  proportion  \
# 0                   4                1              0    1.238761
# 1                   0                2              0    1.357978
# ...

# %%
numeric_columns
# Out:
# ['follower_count',
#  'following_count',
#  'media_count',
#  'isprivate',
#  'label',
#  'bio_len',
#  'name_len',
#  'bio_word_count',
#  'name_word_count',
#  'have_com_links',
#  'have_ru_links',
#  'bio_has_digits',
#  'name_has_digits',
#  'proportion',
#  'digit_count_username']

# %%
plt.figure(figsize=(15,6))
sns.kdeplot(data.loc[data['label'] == 0]['digit_count_username'], shade=True, color="dodgerblue", label="Not fake", alpha=.7)
sns.kdeplot(data.loc[data['label'] == 1]['digit_count_username'], shade=True, color="deeppink", label="Fake", alpha=.7)
plt.title('Count of digits in username', fontsize=16)
plt.legend()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

prepared_corr = data[numeric_columns].corr().round(decimals=2)
plt.figure(figsize=(10,8), dpi= 80)
sns.heatmap(prepared_corr, xticklabels=prepared_corr.columns, yticklabels=prepared_corr.columns, cmap='RdYlGn', center=0, annot=True)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

prepared_corr = data[numeric_columns].corr().round(decimals=2)
plt.figure(figsize=(12,10), dpi= 80)
sns.heatmap(prepared_corr, xticklabels=prepared_corr.columns, yticklabels=prepared_corr.columns, cmap='RdYlGn', center=0, annot=True)

# Decorations
'''plt.title('Correlogram of students dataset', fontsize=22)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()'''

plt.figure(figsize=(15,6))
plt.subplot(121)
sns.distplot(data['follower_count'])
plt.subplot(122)
sns.distplot(data['following_count'])
plt.show()

plt.figure(figsize=(15,6))
plt.subplot(121)
sns.distplot(data['media_count'])
plt.subplot(122)
sns.distplot(data['isprivate'])
plt.show()

plt.figure(figsize=(15,6))
plt.subplot(121)
sns.distplot(data['label'])
plt.subplot(122)
sns.distplot(data['bio_len'])
plt.show()

plt.figure(figsize=(15,6))
plt.subplot(121)
sns.distplot(data['name_len'])
plt.subplot(122)
sns.distplot(data['bio_word_count'])
plt.show()

plt.figure(figsize=(15,6))
plt.subplot(121)
sns.distplot(data['have_com_links'])
plt.subplot(122)
sns.distplot(data['have_ru_links'])
plt.show()

plt.figure(figsize=(15,6))
plt.subplot(121)
sns.distplot(data['bio_has_digits'])
plt.subplot(122)
sns.distplot(data['name_has_digits'])
plt.show()

plt.figure(figsize=(15,6))
plt.subplot(121)
sns.distplot(data['proportion'])
plt.subplot(122)
sns.distplot(data['digit_count_username'])
plt.show()

'''plt.subplot(223)
plt.figure(figsize=(2,2))
sns.distplot(data['media_count'])
plt.subplot(224)
plt.figure(figsize=(2,2))
sns.distplot(data['isprivate'])
plt.show()'''
# Out:
# "plt.subplot(223)\nplt.figure(figsize=(2,2))\nsns.distplot(data['media_count'])\nplt.subplot(224)\nplt.figure(figsize=(2,2))\nsns.distplot(data['isprivate'])\nplt.show()"

# %%
'''for column in numeric_columns:
    plt.figure(figsize=(15,10))
    sns.stripplot(x='label', y=column, data=prepared_data, jitter=True)
    plt.show()'''

labels = ['not fake', 'fake']

plt.figure(figsize=(15,6))
plt.subplot(121)
sns.stripplot(x='label', y='follower_count', data=data, jitter=True)
plt.subplot(122)
sns.stripplot(x='label', y='following_count', data=data, jitter=True)
plt.show()

plt.figure(figsize=(15,6))
plt.subplot(121)
sns.stripplot(x='label', y='media_count', data=data, jitter=True)
plt.subplot(122)
sns.stripplot(x='label', y='isprivate', data=data, jitter=True)
plt.show()

plt.figure(figsize=(15,6))
plt.subplot(121)
sns.stripplot(x='label', y='digit_count_username', data=data, jitter=True)
plt.subplot(122)
sns.stripplot(x='label', y='bio_len', data=data, jitter=True)
plt.show()

plt.figure(figsize=(15,6))
plt.subplot(121)
sns.stripplot(x='label', y='name_len', data=data, jitter=True)
plt.subplot(122)
sns.stripplot(x='label', y='bio_word_count', data=data, jitter=True)
plt.show()

plt.figure(figsize=(15,6))
plt.subplot(121)
sns.stripplot(x='label', y='have_com_links', data=data, jitter=True)
plt.subplot(122)
sns.stripplot(x='label', y='have_ru_links', data=data, jitter=True)
plt.show()

plt.figure(figsize=(15,6))
plt.subplot(121)
sns.stripplot(x='label', y='bio_has_digits', data=data, jitter=True)
plt.subplot(122)
sns.stripplot(x='label', y='name_has_digits', data=data, jitter=True)
plt.show()

plt.figure(figsize=(15,6))
plt.subplot(121)
sns.stripplot(x='label', y='proportion', data=data, jitter=True)
plt.show()

# %% [markdown]
# ## SMOTE

# %%
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.25)
sm = SMOTE(random_state=0)
X_train_sm, y_train_sm = sm.fit_sample(X_train, y_train)
X_train_sm['label'] = y_train_sm
X_train_sm = X_train_sm.sample(frac=1).reset_index(drop=True)
y_train = X_train_sm['label']
X_train = X_train_sm.drop('label', axis=1)
X_train
# Out:
#        follower_count  following_count  media_count  isprivate  \
# 0                  16              114            0          1
# 1                 401             1456            2          0
# 2                1115              698           49          0
# 3                  79             7344          131          0
# 4                 201             6678            0          1
# ...               ...              ...          ...        ...
# 18797             309             6055           12          0
# 18798             268              106            4          0
# 18799            3771             2811          242          0
# 18800            2299             6876          121          0
# 18801             821              441           13          0
#
#        bio_word_count  name_word_count  have_ru_links  proportion  \
# 0                   0                1              0    7.080745
# 1                  13                1              0    3.646295
# ...

# %% [markdown]
# ## Oversampling

# %%
from sklearn.model_selection import train_test_split
from sklearn.utils import resample

X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.25)
X = pd.concat([X_train, y_train], axis=1)
no_fake = X[X.label == 0]
fake = X[X.label == 1]

fake_upsampled = resample(fake,
                          replace=True,
                          n_samples=len(no_fake))
X = pd.concat([fake_upsampled, no_fake])
X = X.sample(frac=1).reset_index(drop=True)
X_train = X.drop(['label'], axis=1)
y_train = X.label
X_train
# Out:
#        follower_count  following_count  media_count  isprivate  \
# 0                 146             1910           18          0
# 1                 802              544           38          0
# 2                 226              940            1          0
# 3                 205              185           30          0
# 4                  47              120            9          0
# ...               ...              ...          ...        ...
# 15189             196              991            1          1
# 15190             787              703            0          1
# 15191             169             7082            7          0
# 15192        30000000              486           30          0
# 15193             477              730          139          0
#
#        bio_word_count  name_word_count  have_ru_links  proportion  \
# 0                  29                2              0   13.073238
# 1                   7                8              0    0.678220
# ...

# %% [markdown]
# ## SMOTENC

# %%
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTENC

X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.25)
sm = SMOTENC(random_state=43, categorical_features=[3, 6])
X_train_sm, y_train_sm = sm.fit_resample(X_train, y_train)

X_train_sm['label'] = y_train_sm
X_train_sm = X_train_sm.sample(frac=1).reset_index(drop=True)
y_train = X_train_sm['label']
X_train = X_train_sm.drop('label', axis=1)
y_train
# Out:
# 0        0
# 1        1
# 2        0
# 3        0
# 4        0
#         ..
# 15221    1
# 15222    1
# 15223    1
# 15224    0
# 15225    0
# Name: label, Length: 15226, dtype: int64

# %% [markdown]
# # Normalizing

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train = pd.DataFrame(scaler.fit_transform(X_train))
X_train
# Out:
#               0         1         2         3         4         5    6  \
# 0     -0.004311 -0.585005  3.957974 -0.769974  1.093487  0.377502  0.0
# 1     -0.101133  2.659012 -0.322974 -0.769974 -0.626762  0.377502  0.0
# 2     -0.100430 -0.483862 -0.237899 -0.769974 -0.626762 -0.541174  0.0
# 3     -0.100325 -0.516955  0.013921 -0.769974 -0.626762  0.377502  0.0
# 4     -0.100868 -0.351025 -0.326377  1.298746  0.328932  0.377502  0.0
# ...         ...       ...       ...       ...       ...       ...  ...
# 13915 -0.099713 -0.495048 -0.244705  1.298746  1.284625 -0.541174  0.0
# 13916 -0.089582 -0.439117  2.205440 -0.769974  2.240319  1.296179  0.0
# 13917 -0.099473 -0.452634  0.030936 -0.769974 -0.053346  1.296179  0.0
# 13918 -0.101201  2.678588 -0.326377  1.298746 -0.053346 -0.541174  0.0
# 13919 -0.100447  2.252578 -0.326377 -0.769974  0.328932  0.377502  0.0
#
#               7         8
# 0     -0.146214 -0.636963
# 1      0.412561  1.622407
# 2     -0.140923  0.869284
# ...

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_test = pd.DataFrame(scaler.fit_transform(X_test))
X_test
# Out:
#              0         1         2         3         4         5         6  \
# 0    -0.070119 -0.177933 -0.246436 -0.531255 -0.619617 -0.058174 -0.256634
# 1    -0.069996  2.259372 -0.251641 -0.531255  1.428301 -0.058174 -0.256634
# 2    -0.070214 -0.611703 -0.256845  1.882336 -0.912177 -0.058174 -0.256634
# 3    -0.070192 -0.556927 -0.261306  1.882336 -0.912177 -1.245542 -0.256634
# 4    -0.070203 -0.616145 -0.211492 -0.531255 -0.327057 -0.651858 -0.256634
# ...        ...       ...       ...       ...       ...       ...       ...
# 2730 -0.070204 -0.557914 -0.258332 -0.531255 -0.912177 -0.651858 -0.256634
# 2731 -0.070101  0.369831  0.346870 -0.531255 -0.473337 -0.058174 -0.256634
# 2732 -0.070060  2.782462 -0.128965 -0.531255 -0.619617  1.722877 -0.256634
# 2733 -0.070178 -0.443920 -0.211492  1.882336 -0.619617 -0.651858 -0.256634
# 2734 -0.070214 -0.625521 -0.258332 -0.531255  1.867141 -0.651858 -0.256634
#
#              7         8
# 0    -0.055581  2.269546
# ...

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import *


def evalulate_classifier(predictions, X_test, y_test, clf):
    print("Accuracy: ", accuracy_score(y_test, predictions))
    print('Precision: ', precision_score(y_test, predictions))
    print('Recall: ', recall_score(y_test, predictions))
    print('f1 micro: ', f1_score(y_test, predictions, average='micro'))
    print('f1 macro: ', f1_score(y_test, predictions, average='macro'))
    y_proba = clf.predict(X_test)
    print('ROC AUC: ', roc_auc_score(y_test, y_proba))
    print('Confusion matrix:\n', pd.DataFrame(confusion_matrix(y_test, predictions)))
    plot_roc_curve(clf, X_test, y_test)
    plt.show() 
    
    plt.figure(figsize=(15,3))
    plt.plot(predictions[:300], 'r-', label='Predicted')
    plt.plot(y_test.values[:300], 'b-', label='True')
    plt.show()

# %%
import warnings
from sklearn.model_selection import GridSearchCV
from sklearn.exceptions import ConvergenceWarning


metrics_cls = ['f1_macro']
def tune_params_classifier(model, parameters, splits, X_train, y_train, metrics):
    for metric in metrics:
        with warnings.catch_warnings():
            warnings.filterwarnings("ignore", category=ConvergenceWarning)
            classifier = GridSearchCV(model, parameters, scoring=metric, cv=splits)
            classifier.fit(X_train, y_train)
            print('****'*10)
            print('Metric:', metric)
            print('Best score:', classifier.best_score_)
            print('Best params:', classifier.best_params_)

# %%
def fit_eval_classifier(clf, X_train, y_train, X_test, y_test):
    clf.fit(X_train, y_train)
    predictions = clf.predict(X_test)
    evalulate_classifier(predictions, X_test, y_test, clf)

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

parameters = {'n_neighbors': range(1, 50, 20), 'weights': ['distance', 'uniform']}

tune_params_classifier(KNeighborsClassifier(), parameters, 5, X_train, y_train, metrics_cls)
# Out:
# ****************************************
# Metric: f1_macro
# Best score: 0.9069549214567388
# Best params: {'n_neighbors': 1, 'weights': 'distance'}

# %%
from sklearn.neighbors import KNeighborsClassifier


knn = KNeighborsClassifier(n_neighbors=1, weights='distance')
fit_eval_classifier(knn, X_train, y_train, X_test, y_test)
# Out:
# Accuracy:  0.8534775888717157
# Precision:  0.06018518518518518
# Recall:  0.2765957446808511
# f1 micro:  0.8534775888717157
# f1 macro:  0.5095575178215946
# ROC AUC:  0.5736687733273724
# Confusion matrix:
#        0    1
# 0  2735  406
# 1    68   26

# %% [markdown]
# ## Logistic regression

# %%
from sklearn.linear_model import LogisticRegression


parameters = {'tol': [1e-10, 1e-8, 1e-6, 1e-4, 1e-2, 1e-1, 1], 'C': [1e-4, 1e-2, 1e-1, 1, 2, 4, 8, 10, 20]}

tune_params_classifier(LogisticRegression(), parameters, 5, X_train, y_train, metrics_cls)
# Out:
# ****************************************
# Metric: f1_macro
# Best score: 0.7314645065979097
# Best params: {'C': 8, 'tol': 1e-10}

# %%
from sklearn.linear_model import LogisticRegression


lr = LogisticRegression(tol=1e-10, C=8)
fit_eval_classifier(lr, X_train, y_train, X_test, y_test)
# Out:
# Accuracy:  0.7097372488408037
# Precision:  0.06308169596690796
# Recall:  0.648936170212766
# f1 micro:  0.7097372488408037
# f1 macro:  0.47069315304945203
# ROC AUC:  0.6802464996240526
# Confusion matrix:
#        0    1
# 0  2235  906
# 1    33   61

# %% [markdown]
# ## Decision tree

# %%
from sklearn.tree import DecisionTreeClassifier

parameters = {'criterion': ['gini', 'entropy'], 'max_depth': range(1, 20)}

tune_params_classifier(DecisionTreeClassifier(), parameters, 10, X_train, y_train, metrics_cls)
# Out:
# ****************************************
# Metric: f1_macro
# Best score: 0.9188839531985329
# Best params: {'criterion': 'gini', 'max_depth': 19}

# %%
from sklearn.tree import DecisionTreeClassifier


decision_tree = DecisionTreeClassifier(criterion='gini', max_depth=19)
fit_eval_classifier(decision_tree, X_train, y_train, X_test, y_test)
# Out:
# Accuracy:  0.8741885625965997
# Precision:  0.08042895442359249
# Recall:  0.3191489361702128
# f1 micro:  0.8741885625965997
# f1 macro:  0.5303401118855277
# ROC AUC:  0.6049740223671821
# Confusion matrix:
#        0    1
# 0  2798  343
# 1    64   30

# %% [markdown]
# ## Random forest

# %%
from sklearn.ensemble import RandomForestClassifier

parameters = {'max_depth': range(1, 15, 3), 'n_estimators': range(1, 150, 25), 'criterion': {'gini', 'entropy'},
             'min_samples_split': [1e-4, 1e-2, 1e-1, 2e-1, 3e-1, 5e-1, 7e-1, 9e-1], 
              'class_weight': ['balanced', 'balanced_subsample']}
parameters =  {'n_estimators': range(1, 150, 30) }

tune_params_classifier(RandomForestClassifier(), parameters, 5, X_train, y_train, metrics_cls)
# Out:
# ****************************************
# Metric: f1_micro
# Best score: 0.9767043132263037
# Best params: {'n_estimators': 91}

# %%
from sklearn.ensemble import RandomForestClassifier


rand_forest = RandomForestClassifier(max_depth=14, class_weight='balanced', min_samples_split=0.0001, n_estimators=78)
fit_eval_classifier(rand_forest, X_train, y_train, X_test, y_test)
# Out:
# Accuracy:  0.8902627511591963
# Precision:  0.11275964391691394
# Recall:  0.40425531914893614
# f1 micro:  0.8902627511591963
# f1 macro:  0.5587747698736251
# ROC AUC:  0.6545313526658403
# Confusion matrix:
#        0    1
# 0  2842  299
# 1    56   38

# %% [markdown]
# ## AdaBoostClassifier

# %%
from sklearn.ensemble import AdaBoostClassifier

parameters = {'learning_rate': [1e-5, 1e-3, 1e-1, 1, 2, 5], 
              'n_estimators': range(1, 101, 3)}
# parameters = {'learning_rate': [1e-5, 1e-3, 1e-1, 1, 2, 5]}
tune_params_classifier(AdaBoostClassifier(), parameters, 5, X_train, y_train, metrics_cls)
# Out:
# ****************************************
# Metric: f1_macro
# Best score: 0.8371350585932602
# Best params: {'learning_rate': 1, 'n_estimators': 100}

# %%
from sklearn.ensemble import AdaBoostClassifier


ada_boost_cls = AdaBoostClassifier(n_estimators=100, learning_rate=1, algorithm='SAMME')
fit_eval_classifier(ada_boost_cls, X_train, y_train, X_test, y_test)
# Out:
# Accuracy:  0.8188562596599691
# Precision:  0.09405940594059406
# Recall:  0.6063829787234043
# f1 micro:  0.8188562596599691
# f1 macro:  0.5306486754147066
# ROC AUC:  0.7157989392184356
# Confusion matrix:
#        0    1
# 0  2592  549
# 1    37   57

# %% [markdown]
# ## EasyEnsembleClassifier

# %%
from imblearn.ensemble import EasyEnsembleClassifier

parameters = {'n_estimators': range(1, 10), 'warm_start': [True, False]}

tune_params_classifier(EasyEnsembleClassifier(), parameters, 5, X_train, y_train, metrics_cls)
# Out:
# ****************************************
# Metric: f1_macro
# Best score: 0.8343192502805094
# Best params: {'n_estimators': 1, 'warm_start': True}

# %%
from imblearn.ensemble import EasyEnsembleClassifier


easy_ensemble = EasyEnsembleClassifier(n_estimators=1, warm_start=True)
fit_eval_classifier(easy_ensemble, X_train, y_train, X_test, y_test)
# Out:
# Accuracy:  0.8290571870170016
# Precision:  0.08944543828264759
# Recall:  0.5319148936170213
# f1 micro:  0.8290571870170016
# f1 macro:  0.5290365857479042
# ROC AUC:  0.6849322955827863
# Confusion matrix:
#        0    1
# 0  2632  509
# 1    44   50

# %% [markdown]
# ## SVC

# %%
from sklearn.svm import SVC, LinearSVC

parameters = {'C': [1e-10, 1e-2, 1e-1, 1, 4, 8, 20], 'kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
             'degree': range(1, 6), 'gamma': ['scale', 'auto'], 'shrinking': [True, False], 'class_weight': [None, 'balanced'],
             'decision_function_shape': ['ovo', 'ovr'], 'tol': [1e-10, 1e-8, 1e-6, 1e-4, 1e-2, 1e-1, 1]}
parameters = {'C': [1e-10, 1e-2, 1, 4, 20], 'kernel': ['poly']}
tune_params_classifier(SVC(), parameters, 5, X_train, y_train, metrics_cls)

# %% [markdown]
# ## BalancedRandomForestClassifier

# %%
from imblearn.ensemble import BalancedRandomForestClassifier


parameters = {'n_estimators': [1, 150, 30]}

tune_params_classifier(BalancedRandomForestClassifier(), parameters, 5, X_train, y_train, metrics_cls)
# Out:
# ****************************************
# Metric: f1_macro
# Best score: 0.9424263059465184
# Best params: {'n_estimators': 150}

# %%
from imblearn.ensemble import BalancedRandomForestClassifier


balanced_rf = BalancedRandomForestClassifier(n_estimators=150)
fit_eval_classifier(balanced_rf, X_train, y_train, X_test, y_test)
# Out:
# Accuracy:  0.9143740340030911
# Precision:  0.1383399209486166
# Recall:  0.3723404255319149
# f1 micro:  0.9143740340030913
# f1 macro:  0.5782449224142353
# ROC AUC:  0.6514678886653525
# Confusion matrix:
#        0    1
# 0  2923  218
# 1    59   35

# %% [markdown]
# ## BalancedBaggingClassifier

# %%
from imblearn.ensemble import BalancedBaggingClassifier

parameters = {'n_estimators': [1, 150, 30]}
tune_params_classifier(BalancedBaggingClassifier(), parameters, 5, X_train, y_train, metrics_cls)
# Out:
# ****************************************
# Metric: f1_macro
# Best score: 0.944868194625716
# Best params: {'n_estimators': 150}

# %%
from imblearn.ensemble import BalancedBaggingClassifier


balanced_bag_cls = BalancedRandomForestClassifier(n_estimators=150)
fit_eval_classifier(balanced_bag_cls, X_train, y_train, X_test, y_test)
# Out:
# Accuracy:  0.9156105100463678
# Precision:  0.14056224899598393
# Recall:  0.3723404255319149
# f1 micro:  0.9156105100463678
# f1 macro:  0.5797623766333692
# ROC AUC:  0.6521046285571067
# Confusion matrix:
#        0    1
# 0  2927  214
# 1    59   35

# %% [markdown]
# ## BaggingClassifier

# %%
from sklearn.ensemble import BaggingClassifier

parameters = {'n_estimators': [1, 150, 5]}
tune_params_classifier(BaggingClassifier(), parameters, 5, X_train, y_train, metrics_cls)
# Out:
# ****************************************
# Metric: f1_macro
# Best score: 0.9451363055160875
# Best params: {'n_estimators': 150}

# %%
from sklearn.ensemble import BaggingClassifier


bagging_cls = BaggingClassifier(n_estimators=150)
fit_eval_classifier(bagging_cls, X_train, y_train, X_test, y_test)
# Out:
# Accuracy:  0.912210200927357
# Precision:  0.11693548387096774
# Recall:  0.30851063829787234
# f1 micro:  0.912210200927357
# f1 macro:  0.5616229978776357
# ROC AUC:  0.6193938100753927
# Confusion matrix:
#        0    1
# 0  2922  219
# 1    65   29

# %%
from sklearn.ensemble import ExtraTreesClassifier

parameters = {'n_estimators': [1, 150, 30]}
tune_params_classifier(ExtraTreesClassifier(), parameters, 5, X_train, y_train, metrics_cls)
# Out:
# ****************************************
# Metric: f1_macro
# Best score: 0.9753302903524295
# Best params: {'n_estimators': 150}

# %%
etc = ExtraTreesClassifier(random_state=0, n_estimators=150)

fit_eval_classifier(etc, X_train, y_train, X_test, y_test)
# Out:
# Accuracy:  0.9583180987202925
# Precision:  0.7258064516129032
# Recall:  0.7964601769911505
# f1:  0.8683377081411965
# ROC AUC:  0.8846788728718207
# Confusion matrix:
#        0    1
# 0  2441   68
# 1    46  180

# %%
from sklearn.ensemble import GradientBoostingClassifier

parameters = {'n_estimators': [1, 300, 5]}
tune_params_classifier(GradientBoostingClassifier(), parameters, 5, X_train, y_train, metrics_cls)
# Out:
# ****************************************
# Metric: f1_macro
# Best score: 0.9739696870032603
# Best params: {'n_estimators': 300}

# %%
gbc = GradientBoostingClassifier(random_state=0, n_estimators=300)

fit_eval_classifier(gbc, X_train, y_train, X_test, y_test)
# Out:
# Accuracy:  0.9630712979890311
# Precision:  0.7256317689530686
# Recall:  0.8893805309734514
# f1:  0.8894352828068832
# ROC AUC:  0.9295447892013531
# Confusion matrix:
#        0    1
# 0  2433   76
# 1    25  201

# %% [markdown]
# # Neural networks

# %%
import tensorflow as tf
import math
from tensorflow import keras
from sklearn.utils import resample
from tensorflow.keras.models import Sequential
from tensorflow.keras import regularizers
from tensorflow.keras.layers import Dense, Dropout
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import numpy
from imblearn.over_sampling import SMOTE
from sklearn.datasets import make_circles
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix



from tensorflow.keras.layers import Layer
from tensorflow.keras import backend as K

def f1(y_true, y_pred):
    def recall(y_true, y_pred):
        """Recall metric.

        Only computes a batch-wise average of recall.

        Computes the recall, a metric for multi-label classification of
        how many relevant items are selected.
        """
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + K.epsilon())
        return recall

    def precision(y_true, y_pred):
        """Precision metric.

        Only computes a batch-wise average of precision.

        Computes the precision, a metric for multi-label classification of
        how many selected items are relevant.
        """
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision
    precision = precision(y_true, y_pred)
    recall = recall(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))


# для воспроизводимости результатов
numpy.random.seed(2)

model = Sequential()
model.add(Dense(75, input_dim=9, activation='sigmoid'))
model.add(Dense(75, activation='relu'))
model.add(Dense(1, activation='sigmoid', kernel_regularizer=regularizers.l2(0.01)))

# компилируем модель, используем градиентный спуск adam
model.compile(loss="binary_crossentropy", optimizer="adam", metrics=['binary_accuracy'])
print(model.summary())

    
# обучаем нейронную сеть
model.fit(X_train, y_train, epochs = 10, batch_size=64)

features_test = X_test
labels_test = y_test

predictions = model.predict_classes(features_test)
probs = model.predict(features_test)
predictions = predictions[:, 0]
probs = probs[:, 0]

tn = ['Normal', 'Fake']
matrix = confusion_matrix(labels_test, predictions)
print(matrix)
print(classification_report(labels_test, predictions, target_names=tn))
print('F1 macro', f1_score(labels_test, predictions, average='macro'))
# Out:
# Model: "sequential_16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_48 (Dense)             (None, 75)                750
# _________________________________________________________________
# dense_49 (Dense)             (None, 75)                5700
# _________________________________________________________________
# dense_50 (Dense)             (None, 1)                 76
# ...
# Total params: 6,526
# Trainable params: 6,526
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 218/218 [==============================] - 1s 2ms/step - loss: 0.6270 - binary_accuracy: 0.7239
# Epoch 2/10
# 218/218 [==============================] - 0s 2ms/step - loss: 0.4869 - binary_accuracy: 0.7886
# Epoch 3/10
# 218/218 [==============================] - 0s 2ms/step - loss: 0.4590 - binary_accuracy: 0.8023
# Epoch 4/10
# ...

# %%
import kerastuner
from kerastuner.tuners import RandomSearch, Hyperband, BayesianOptimization
from tensorflow import keras

def build_model(hp):
    model = keras.Sequential()
    # activation_choice = hp.Choice('activation', values=['relu', 'sigmoid', 'tanh', 'elu', 'selu'])    
    model.add(keras.layers.Dense(units=hp.Int('units_input',
                                   min_value=9,
                                   max_value=100,
                                   step=50),
                    input_dim=X_train.shape[1],
                    activation='sigmoid'))
    model.add(keras.layers.Dense(units=hp.Int('units_hidden',        
                                   min_value=2,   
                                   max_value=100,   
                                   step=1),
                    activation='relu'))   
    model.add(keras.layers.Dense(1, activation = "sigmoid"))
    model.compile(
        optimizer='adam',
        loss='binary_crossentropy',
        metrics=[f1])
    return model

# %%
tuner = RandomSearch(
    build_model,
    objective=kerastuner.Objective("val_f1", direction="max"),
    max_trials=80,
    directory='.models'
    )
# Out:
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.

# %%
tuner.search_space_summary()
# Out:
# <span style="color:#4527A0"><h1 style="font-size:18px">Search space summary</h1></span>
# <span style="color:cyan"> |-Default search space size: 2</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">units_input (Int)</h2></span>
# <span style="color:cyan"> |-conditions: []</span>
# <span style="color:blue"> |-default: None</span>
# <span style="color:cyan"> |-max_value: 100</span>
# <span style="color:blue"> |-min_value: 9</span>
# <span style="color:cyan"> |-sampling: None</span>
# <span style="color:blue"> |-step: 50</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">units_hidden (Int)</h2></span>
# <span style="color:cyan"> |-conditions: []</span>
# <span style="color:blue"> |-default: None</span>
# <span style="color:cyan"> |-max_value: 100</span>
# <span style="color:blue"> |-min_value: 2</span>
# <span style="color:cyan"> |-sampling: None</span>
# <span style="color:blue"> |-step: 1</span>

# %%
tuner.search(X_train,                  # Данные для обучения
             y_train,                  # Правильные ответы
             batch_size=100,             # Размер мини-выборки
             epochs=10,                # Количество эпох обучения 
             validation_split=0.2,    # Часть данных, которая будет использоваться для проверки
             verbose=1
             )
# Out:
# Epoch 1/10
# 112/112 [==============================] - ETA: 0s - loss: 0.8377 - f1: 0.0000e+ - ETA: 0s - loss: 0.7261 - f1: 0.1758   - ETA: 0s - loss: 0.6829 - f1: 0.53 - ETA: 0s - loss: 0.6510 - f1: 0.63 - ETA: 0s - loss: 0.6322 - f1: 0.67 - ETA: 0s - loss: 0.6111 - f1: 0.69 - ETA: 0s - loss: 0.5956 - f1: 0.71 - 1s 7ms/step - loss: 0.5914 - f1: 0.7156 - val_loss: 0.5021 - val_f1: 0.7925
# Epoch 2/10
# 112/112 [==============================] - ETA: 0s - loss: 0.6092 - f1: 0.70 - ETA: 0s - loss: 0.4947 - f1: 0.78 - ETA: 0s - loss: 0.4876 - f1: 0.78 - ETA: 0s - loss: 0.4776 - f1: 0.79 - ETA: 0s - loss: 0.4785 - f1: 0.79 - ETA: 0s - loss: 0.4730 - f1: 0.79 - 0s 4ms/step - loss: 0.4715 - f1: 0.7969 - val_loss: 0.4600 - val_f1: 0.8077
# Epoch 3/10
# ...

# %%
tuner.results_summary()
# Out:
# <span style="color:#4527A0"><h1 style="font-size:18px">Results summary</h1></span>
# <span style="color:cyan"> |-Results in .models\untitled_project</span>
# <span style="color:cyan"> |-Showing 10 best trials</span>
# <span style="color:cyan"> |-Objective(name='val_f1', direction='max')</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:cyan"> |-Trial ID: c2263188a744b1342f3d48ee19404bd6</span>
# <span style="color:cyan"> |-Score: 0.9115118980407715</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hyperparameters:</h2></span>
# <span style="color:cyan"> |-units_hidden: 42</span>
# <span style="color:blue"> |-units_input: 59</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:cyan"> |-Trial ID: 88592cb21b9ee9090e95223f8a93f75f</span>
# <span style="color:cyan"> |-Score: 0.9112223982810974</span>
# ...

# %%
models = tuner.get_best_models()

# %%
for model in models:
    model.summary()
    model.evaluate(X_test, y_test)
    print('*****'*8)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 59)                590
# _________________________________________________________________
# dense_1 (Dense)              (None, 42)                2520
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 43
# ...
# Total params: 3,153
# Trainable params: 3,153
# Non-trainable params: 0
# _________________________________________________________________
# 86/86 [==============================] - ETA: 0s - loss: 0.3433 - f1: 0.28 - ETA: 0s - loss: 0.3891 - f1: 0.45 - ETA: 0s - loss: 0.3757 - f1: 0.40 - 0s 2ms/step - loss: 0.3717 - f1: 0.4126
# ****************************************
